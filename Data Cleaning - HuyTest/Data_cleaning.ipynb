# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Bước 1 Xử lý những Giá trị thiếu (Missing values) và xóa những cột không quan trọng

# %%
import pandas as pd 
import numpy as np
# 1. Đọc dữ liệu từ file gốc
df = pd.read_csv('Bangladesh_database_Final_Merged.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4608 entries, 0 to 4607
# Data columns (total 61 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Area                    4608 non-null   int64
#  1   AP Ratio                4608 non-null   object
#  2   District                4608 non-null   object
#  3   Season                  4608 non-null   object
#  4   Avg Temp                4608 non-null   float64
#  5   Avg Humidity            4608 non-null   float64
#  6   Crop Name               4608 non-null   object
#  7   Transplant              4608 non-null   object
#  8   Growth                  4608 non-null   object
#  9   Harvest                 4608 non-null   object
#  10  Production              4608 non-null   int64
#  11  Max Temp                4608 non-null   int64
#  12  Min Temp                4608 non-null   float64
#  13  Max Relative Humidity   4608 non-null   int64
#  14  Min Relative Humidity   4608 non-null   int64
#  15  Year                    4608 non-null   int64
#  16  EVI                     4608 non-null   float64
#  17  LAI                     4608 non-null   float64
#  18  FPAR                    4608 non-null   float64
#  19  LST_Kelvin              4608 non-null   float64
#  20  Soil_Moisture_mm        4608 non-null   float64
#  21  NDVI_Season_Mean        4608 non-null   float64
#  22  NDVI_Season_Max         4608 non-null   float64
#  23  NDVI_Season_Min         4608 non-null   float64
#  24  NDVI_Season_Std         4608 non-null   float64
#  25  NDVI_Season_Range       4608 non-null   float64
#  26  NDVI_Season_CV          4608 non-null   float64
#  27  Avg_Salinity_Index      4608 non-null   float64
#  28  pH                      4608 non-null   float64
#  29  Organic_Carbon          4608 non-null   float64
#  30  Nitrogen                4608 non-null   float64
#  31  Clay                    4608 non-null   float64
#  32  Sand                    4608 non-null   float64
#  33  Silt                    4608 non-null   float64
#  34  Bulk_Density            4608 non-null   float64
#  35  valid_points            4608 non-null   int64
#  36  grid_log                4608 non-null   object
#  37  Latitude                4608 non-null   float64
#  38  Longitude               4608 non-null   float64
#  39  CN_Ratio                4608 non-null   float64
#  40  pH_Suitability          4608 non-null   object
#  41  Compaction_Risk         4608 non-null   object
#  42  Dominant_Soil_Texture   4608 non-null   object
#  43  sm_surface              4608 non-null   float64
#  44  sm_rootzone             4608 non-null   float64
#  45  Rootzone_Surface_Diff   4608 non-null   float64
#  46  Moisture_Ratio          4608 non-null   float64
#  47  Water_Availability_Cat  4608 non-null   object
#  48  Rainfall                4608 non-null   float64
#  49  Temp_Mean               4608 non-null   float64
#  50  Temp_Max                4608 non-null   float64
#  51  Temp_Min                4608 non-null   float64
#  52  Heat_Stress_Days        4608 non-null   int64
#  53  Wind_Mean               4608 non-null   float64
#  54  Wind_Max                4608 non-null   float64
#  55  Wind_Min                4608 non-null   float64
#  56  Temp_Range              4608 non-null   float64
#  57  Wind_Range              4608 non-null   float64
#  58  Rain_Temp_Ratio         4608 non-null   float64
#  59  Extreme_Heat_Risk       4608 non-null   object
#  60  Is_Extreme_Heat         4608 non-null   int64
# dtypes: float64(39), int64(9), object(13)
# memory usage: 2.1+ MB

# %%
df
# Out:
# 211      101    2.217821782           Barguna      Rabi     25.00
# 212        0        #DIV/0!           Barguna  Kharif 1     11.50
# 213       23    1.695652174           Barguna  Kharif 1     27.50
# 214     1462     0.53625171           Barguna  Kharif 1     29.00
# 215        0        #DIV/0!           Barguna  Kharif 1     21.50
# 216     1800   0.9422222222          Barishal      Rabi     17.75
# 217      660              2          Barishal      Rabi     20.50
# 218   130120     1.61278051          Barishal      Rabi     26.00
# 219     4580    3.672925764          Barishal      Rabi     20.50
# 220    27465   0.3897687967          Barishal  Kharif 1     31.50
# 221      500         17.202          Barishal  Kharif 1     34.50
# 222      170    13.70588235          Barishal  Kharif 1     30.00
# 223    44719   0.7564793488          Barishal  Kharif 1     26.00
# 224      416    1.514423077          Barishal      Rabi     25.50
# 225     1222    5.373977087          Barishal  Kharif 2     29.00
# 226     1373    3.510560816          Barishal  Kharif 1     25.00
# 227     1351    4.071058475          Barishal  Kharif 1     25.00
# 228      190   0.4210526316          Barishal  Kharif 1     27.50
# 229      563   0.9253996448          Barishal  Kharif 1     25.00
# 230     6623    2.039710101          Barishal  Kharif 1     25.00
# 231       39    4.256410256          Barishal  Kharif 2     23.50
# 232      325    1.347692308          Barishal  Kharif 2     25.00
# 233      472    1.896186441          Barishal  Kharif 2     21.00
# 234      681    2.720998532          Barishal  Kharif 2     21.00
# 235     1510   0.4728476821          Barishal      Rabi     31.00
# 236      328    1.384146341          Barishal  Kharif 2     25.00
# 237      459    2.169934641          Barishal  Kharif 2     19.00
# 238      431    3.475638051          Barishal  Kharif 2     17.00
# 239        0        #DIV/0!          Barishal      Rabi     21.00
# 240        0        #DIV/0!          Barishal  Kharif 2     17.50
# 241     2026   0.5113524186          Barishal  Kharif 2     22.50
# 242      823    2.430133657          Barishal  Kharif 1     20.50
# 243     4293   0.4346610762          Barishal  Kharif 2     15.00
# 244      333    1.501501502          Barishal      Rabi     20.00
# 245      281   0.8790035587          Barishal  Kharif 1     32.50
# 246     1760    3.284659091          Barishal      Rabi     25.00
# 247     1005    1.412935323          Barishal      Rabi     17.50
# 248      106    1.452830189          Barishal  Kharif 1     24.00
# 249        0        #DIV/0!          Barishal  Kharif 2     27.50
# 250      790    4.658227848          Barishal  Kharif 2     26.50
# 251     6424   0.4403798257          Barishal  Kharif 2     30.00
# 252      439    2.041002278          Barishal  Kharif 1     22.50
# 253      288    1.402777778          Barishal  Kharif 1     25.00
# 254      506     1.62055336          Barishal  Kharif 2     25.00
# 255      841    1.118906064          Barishal  Kharif 2     30.00
# 256      334    1.856287425          Barishal  Kharif 1     23.00
# 257       28    1.607142857          Barishal  Kharif 2     26.50
# 258        0        #DIV/0!          Barishal  Kharif 1     27.00
# 259      423    1.628841608          Barishal  Kharif 1     20.00
# 260        0        #DIV/0!          Barishal  Kharif 2     18.00
# 261      827    2.828295042          Barishal  Kharif 2     16.00
# 262     8510   0.4124559342          Barishal      Rabi     22.50
# 263      560    1.569642857          Barishal      Rabi     20.00
# 264        0        #DIV/0!          Barishal      Rabi     20.00
# 265       28            0.5          Barishal  Kharif 2     22.50
# Temp_Range                0
# Wind_Range                0
# Rain_Temp_Ratio           0
# Extreme_Heat_Risk         0
# Is_Extreme_Heat           0
# dtype: int64

# %% [markdown]
# #### Xóa những cột không liên quan

# %%
# Danh sách các cột đề xuất xóa
cols_to_drop = [
    # 1. Dữ liệu định danh/vị trí không đóng góp vào mô hình chung
    'grid_log',        # Thường là mã định danh lưới địa lý
    'valid_points',    # Chỉ số kỹ thuật khi thu thập dữ liệu
    'Latitude',        # Đã có cột 'District' đại diện cho khu vực
    'Longitude',       # Đã có cột 'District' đại diện cho khu vực
    
    # 2. Cột trùng lặp thông tin hoặc tính toán trực tiếp từ cột khác
    # Các cột Temp_Mean, Temp_Max... thường trùng lặp với Avg Temp, Max Temp
    'Temp_Mean',       # Trùng lặp với Avg Temp
    'Temp_Max',        # Trùng lặp với Max Temp
    'Temp_Min',        # Trùng lặp với Min Temp
    'Temp_Range',      # Có thể tính bằng Max - Min
    'Wind_Range'      # Có thể tính bằng Max - Min
    
    # 3. Cột chứa thông tin về Target (nếu bạn dự báo Production thì xóa AP Ratio và ngược lại)
    # Ở đây chúng ta giữ AP Ratio làm target chính, nên có thể cân nhắc xóa:
    
]

# Thực hiện xóa
df = df.drop(columns=cols_to_drop)

print(f"Số lượng cột còn lại: {df.shape[1]}")
print("Các cột đã giữ lại bao gồm các chỉ số quan trọng về Soil, NDVI, Weather và Crop Info.")
# Out:
# Số lượng cột còn lại: 52
# Các cột đã giữ lại bao gồm các chỉ số quan trọng về Soil, NDVI, Weather và Crop Info.

# %% [markdown]
# ## Bước 2 :Xử lý những giá trị trùng lặp

# %%
df = df.drop_duplicates()

# %% [markdown]
# ## Bước 3 : Xử lý lỗi sai định dạng

# %%
# Giả sử bạn tiếp tục với df đã được xóa dòng lỗi ở bước trước
# df = pd.read_csv('Bangladesh_database_Cleaned_Step1.csv')

# 1. Danh sách các cột phân loại cần chuẩn hóa định dạng chuỗi
categorical_cols = [
    'District', 'Season', 'Crop Name', 'Transplant', 'Growth', 'Harvest', 
    'pH_Suitability', 'Compaction_Risk', 'Dominant_Soil_Texture', 
    'Water_Availability_Cat', 'Extreme_Heat_Risk'
]

for col in categorical_cols:
    if col in df.columns:
        # Xóa khoảng trắng thừa ở đầu/cuối và chuyển về chữ in hoa đầu từ (Capitalize)
        # Việc này giúp tránh trường hợp 'Jashore' và 'Jashore ' bị coi là 2 quận khác nhau
        df[col] = df[col].astype(str).str.strip().str.title()

# 2. Xử lý riêng các cột chu kỳ mùa vụ (thường bị sai định dạng dải tháng)
# Ví dụ: "April to Aug" vs "April-Aug"
date_cols = ['Transplant', 'Growth', 'Harvest']
for col in date_cols:
    if col in df.columns:
        df[col] = df[col].str.replace(' To ', ' to ', case=False)
        df[col] = df[col].str.replace('-', ' to ')

# 3. Ép kiểu dữ liệu số cho các cột tọa độ và chỉ số môi trường 
# (Đảm bảo không còn định dạng 'object' do dữ liệu nhiễu)
numeric_fix_cols = [
    'Avg Temp', 'Avg Humidity', 'Max Temp', 'Min Temp', 
    'Rainfall', 'Wind_Mean', 'pH'
]

for col in numeric_fix_cols:
    if col in df.columns:
        # Chuyển đổi sang số, các giá trị lỗi định dạng không chuyển được sẽ thành NaN
        df[col] = pd.to_numeric(df[col], errors='coerce')

# 4. Xử lý giá trị NaN sau khi ép kiểu (nếu có)
# Điền NaN bằng giá trị trung bình của cột đó để tránh lỗi mô hình
for col in numeric_fix_cols:
    if df[col].isnull().any():
        df[col] = df[col].fillna(df[col].mean())

# 5. Kiểm tra kết quả
print("Đã chuẩn hóa định dạng cho các cột phân loại và số.")
print(df[categorical_cols].head())
# Out:
# Đã chuẩn hóa định dạng cho các cột phân loại và số.
#    District    Season     Crop Name Transplant          Growth        Harvest  \
# 0  Bagerhat      Rabi         Wheat        Dec  Jan  to  March          April
# 1  Bagerhat      Rabi       Maize 2        Dec  Jan  to  March          April
# 2  Bagerhat      Rabi          Boro        Nov    Dec to March          April
# 3  Bagerhat      Rabi  Sweet Potato        Nov    Dec to March          April
# 4  Bagerhat  Kharif 1         Mango      April   No Need to Do  April to June
#
#      pH_Suitability Compaction_Risk Dominant_Soil_Texture  \
# 0  Optimal (Tối Ưu)             Low   Loamy (Thịt/Phù Sa)
# 1  Optimal (Tối Ưu)             Low   Loamy (Thịt/Phù Sa)
# 2  Optimal (Tối Ưu)             Low   Loamy (Thịt/Phù Sa)
# 3  Optimal (Tối Ưu)             Low   Loamy (Thịt/Phù Sa)
# 4  Optimal (Tối Ưu)             Low   Loamy (Thịt/Phù Sa)
#
#   Water_Availability_Cat Extreme_Heat_Risk
# 0                Optimal          Low Risk
# 1                Optimal          Low Risk
# 2                Optimal          Low Risk
# 3                Optimal          Low Risk
# 4                Optimal         High Risk

# %%
df.head()
# Out:
#      Area      AP Ratio  District    Season  Avg Temp  Avg Humidity  \
# 0     259  0.7722007722  Bagerhat      Rabi     17.75          55.0
# 1     421   2.247030879  Bagerhat      Rabi     20.50          60.0
# 2  145439   1.847881242  Bagerhat      Rabi     26.00          72.5
# 3     627    3.50877193  Bagerhat      Rabi     20.50          80.0
# 4     383   4.994778068  Bagerhat  Kharif 1     31.50          70.0
#
#       Crop Name Transplant          Growth        Harvest  ...  \
# 0         Wheat        Dec  Jan  to  March          April  ...
# 1       Maize 2        Dec  Jan  to  March          April  ...
# 2          Boro        Nov    Dec to March          April  ...
# 3  Sweet Potato        Nov    Dec to March          April  ...
# 4         Mango      April   No Need to Do  April to June  ...
#
#    Moisture_Ratio  Water_Availability_Cat  Rainfall  Heat_Stress_Days  \
# 0          1.4035                 Optimal    220.43                 0
# 1          1.4035                 Optimal    220.43                 0
# 2          1.3611                 Optimal    220.43                 0
# 3          1.3611                 Optimal    220.43                 0
# 4          1.3033                 Optimal    656.33                54
#
#    Wind_Mean  Wind_Max  Wind_Min  Rain_Temp_Ratio  Extreme_Heat_Risk  \
# 0   1.452917      4.33      0.04            11.23           Low Risk
# 1   1.452917      4.33      0.04            11.23           Low Risk
# 2   1.452917      4.33      0.04            11.23           Low Risk
# 3   1.452917      4.33      0.04            11.23           Low Risk
# 4   2.481885      5.86      0.04            22.73          High Risk
#
#    Is_Extreme_Heat
# 0                0
# 1                0
# 2                0
# 3                0
# 4                1
#
# [5 rows x 52 columns]

# %% [markdown]
# ## Bước 4: Xử lý những giá trị sai hoặc bất hợp lý (Invaild/incorrect data)

# %% [markdown]
# #### 2. Xử lý lỗi #DIV/0! trong cột 'AP Ratio'
# Thay thế chuỗi lỗi bằng NaN và chuyển sang kiểu số (float)
# Xóa những cột target lỗi

# %%
initial_count = len(df)
df['AP Ratio'] = df['AP Ratio'].replace('#DIV/0!', np.nan)
df['AP Ratio'] = pd.to_numeric(df['AP Ratio'], errors='coerce')
condition_to_drop = (df['Production'] <= 0) | (df['Area'] <= 0) | (df['AP Ratio'].isna())
df = df.drop(df[condition_to_drop].index)
final_count = len(df)
print(f"Số lượng dòng ban đầu: {initial_count}")
print(f"Số lượng dòng đã xóa: {initial_count - final_count}")
print(f"Số lượng dòng còn lại sau khi làm sạch: {final_count}")
# Out:
# Số lượng dòng ban đầu: 4608
# Số lượng dòng đã xóa: 429
# Số lượng dòng còn lại sau khi làm sạch: 4179

# %% [markdown]
# #### Xem Dữ liệu crop name có bao nhiêu loại cây

# %%
df.columns = df.columns.str.strip()

crop_count = df['Crop Name'].value_counts()
print(crop_count)
# Out:
# Crop Name
# Beans             64
# Danta Shak        64
# Cucumber          64
# Lal Shak          64
# Laushak           64
# Boroi             64
# Aman              64
# Banana            64
# Lemon             64
# Guava             64
# Onion             64
# Gourd             64
# Betelnut          64
# Chalkumra         64
# Chili             64
# Black Berry       64
# Radish            64
# Jhinga            64
# Danta             64
# Cabbage           64
# Cauliflower       64
# Garlic            64
# Sugarcane         64
# Boro              64
# Sweet Potato      64
# Mango             64
# Jack Fruit        64
# Ripe Papaya       64
# Aus               64
# Karala            64
# Green Papaya      64
# Jambura           64
# Amra              64
# Wood Apple        64
# Green Coconut     64
# Pumpkin           64
# Barbati           64
# Puishak           64
# Palong Shak       64
# Lady’S Finger     64
# Taramind          63
# Kakrol            63
# Rape & Mustard    63
# Maize 2           62
# Lentil            62
# Green Palmyra     62
# Sesame            61
# Date Palm         60
# Groundnut         60
# Kolmi Shak        59
# Dalim             59
# Mug               58
# Jamrul            58
# Wheat             57
# Motor             55
# Mashkalai         54
# Ginger            53
# Carrot            53
# Mukhi Kachu       53
# Patal             52
# Jute              51
# Gram              49
# Safeda            47
# Palmyra Palm      45
# Pineapple         41
# Oal Kachu         38
# Maize 1           36
# Shalgom           35
# Malta             34
# Arhar             33
# Tobacco           24
# Cheena            18
# #Ref!              1
# Name: count, dtype: int64

# %% [markdown]
# ### Xóa giá trị lỗi trong crop name

# %%
df = df[df['Crop Name'].str.strip() != '#Ref!']
df['Crop Name'].value_counts()
# Out:
# Crop Name
# Beans             64
# Danta Shak        64
# Cucumber          64
# Lal Shak          64
# Laushak           64
# Boroi             64
# Aman              64
# Banana            64
# Lemon             64
# Guava             64
# Onion             64
# Gourd             64
# Betelnut          64
# Chalkumra         64
# Chili             64
# Black Berry       64
# Radish            64
# Jhinga            64
# Danta             64
# Cabbage           64
# Cauliflower       64
# Garlic            64
# Sugarcane         64
# Boro              64
# Sweet Potato      64
# Mango             64
# Jack Fruit        64
# Ripe Papaya       64
# Aus               64
# Karala            64
# Green Papaya      64
# Jambura           64
# Amra              64
# Wood Apple        64
# Green Coconut     64
# Pumpkin           64
# Barbati           64
# Puishak           64
# Palong Shak       64
# Lady’S Finger     64
# Taramind          63
# Kakrol            63
# Rape & Mustard    63
# Maize 2           62
# Lentil            62
# Green Palmyra     62
# Sesame            61
# Date Palm         60
# Groundnut         60
# Kolmi Shak        59
# Dalim             59
# Mug               58
# Jamrul            58
# Wheat             57
# Motor             55
# Mashkalai         54
# Carrot            53
# Ginger            53
# Mukhi Kachu       53
# Patal             52
# Jute              51
# Gram              49
# Safeda            47
# Palmyra Palm      45
# Pineapple         41
# Oal Kachu         38
# Maize 1           36
# Shalgom           35
# Malta             34
# Arhar             33
# Tobacco           24
# Cheena            18
# Name: count, dtype: int64

# %%
str_cols = df.select_dtypes(include=['object']).columns

for col in str_cols:
    print(f"\nColumn: {col}")
    print(df[col].unique())
# Out:
# Column: District
# ['Bagerhat' 'Bandarban' 'Barguna' 'Barishal' 'Bhola' 'Bogura'
#  'Brahmanbaria' 'Chandpur' 'Chapai Nawabganj' 'Chattogram' 'Chuadanga'
#  'Coxsbazar' 'Cumilla' 'Dhaka' 'Dinajpur' 'Faridpur' 'Feni' 'Gaibandha'
#  'Gazipur' 'Gopalganj' 'Habiganj' 'Jamalpur' 'Jashore' 'Jhallokati'
#  'Jhenaidah' 'Joypurhat' 'Khagrachari' 'Khulna' 'Kishoreganj' 'Kurigram'
#  'Kushtia' 'Lakshmipur' 'Lalmonirhat' 'Madaripur' 'Magura' 'Manikganj'
#  'Meherpur' 'Moulvibazar' 'Munshiganj' 'Mymensingh' 'Naogaon' 'Narail'
#  'Narayanganj' 'Narsingdi' 'Natore' 'Netrokona' 'Nilphamari' 'Noakhali'
#  'Pabna' 'Panchagar' 'Patuakhali' 'Pirojpur' 'Rajbari' 'Rajshahi'
#  'Rangamati' 'Rangpur' 'Satkhira' 'Shariatpur' 'Sherpur' 'Sirajganj'
#  'Sunamganj' 'Sylhet' 'Tangail' 'Thakurgaon']
#
# Column: Season
# ['Rabi' 'Kharif 1' 'Kharif 2']
#
# Column: Crop Name
# ['Wheat' 'Maize 2' 'Boro' 'Sweet Potato' 'Mango' 'Jack Fruit'
#  'Ripe Papaya' 'Aus' 'Karala' 'Sugarcane' 'Green Papaya' 'Amra'
#  'Wood Apple' 'Green Coconut' 'Oal Kachu' 'Barbati' 'Puishak'
#  'Palong Shak' 'Sesame' 'Garlic' 'Cauliflower' 'Cabbage' 'Rape & Mustard'
#  'Date Palm' 'Lentil' 'Boroi' 'Taramind' 'Banana' 'Lemon' 'Safeda' 'Patal'
#  'Gourd' 'Betelnut' 'Chalkumra' 'Kakrol' 'Black Berry' 'Jamrul' 'Jhinga'
#  'Pineapple' 'Lady’S Finger' 'Carrot' 'Radish' 'Chili' 'Onion' 'Ginger'
#  'Motor' 'Groundnut' 'Cucumber' 'Green Palmyra' 'Mug' 'Jambura' 'Gram'
#  'Beans' 'Aman' 'Palmyra Palm' 'Pumpkin' 'Lal Shak' 'Laushak' 'Shalgom'
#  'Jute' 'Danta Shak' 'Danta' 'Mukhi Kachu' 'Kolmi Shak' 'Guava' 'Malta'
#  'Cheena' 'Tobacco' 'Maize 1' 'Arhar' 'Dalim' 'Mashkalai']
#
# Column: Transplant
# ['Dec' 'Nov' 'April' 'March' 'Feb' 'Oct' 'June' 'May' 'Sep' 'Aug' 'July'
#  'February' 'Jan' 'September' 'August' 'January' 'October' 'December'
#  'November']
#
# Column: Growth
# ['Jan  to  March' 'Dec to March' 'No Need to Do' 'April to July'
#  'March to July' 'Nov to Aug' 'June to August' 'Oct to Dec' 'Sep to Jan'
#  'Dec to Jan' 'Nov to Jan' 'Oct to Jan' 'Nov to Feb' 'Nov  to  Feb'
#  'March to April' 'Jan to Jan' 'Aug to Jan' 'May to July' 'July to August'
#  'May to June' 'Sep to May' 'Nov to March' 'March to May' 'Sep to Oct'
#  'July to Nov' 'July to  Oct' 'Oct to Nov' 'April to Aug' 'May to Sep'
#  'Dec to Feb' 'April to May']
#
# Column: Harvest
# ['April' 'April to June' 'April to May' 'Aug' 'Aug to Sep'
#  'August to September' 'Dec to Feb' 'December to April' 'Feb'
#  'Feb to April' 'Feb to March' 'February to March' 'February to May' 'Jan'
#  'Jan to March' 'July to Oct' 'July to Sep' 'June  to September'
#  'June to Aug' 'June to Sep' 'March' 'March to April' 'March to Jun' 'May'
#  'May to June' 'Nov' 'Nov to April' 'Nov to Dec' 'Nov to Feb' 'Sep'
#  'Sep to Feb' 'Sep to Oct' 'Throuout The Year' 'June to July']
#
# Column: pH_Suitability
# ['Optimal (Tối Ưu)' 'Acidic (Chua)']
#
# Column: Compaction_Risk
# ['Low']
#
# Column: Dominant_Soil_Texture
# ['Loamy (Thịt/Phù Sa)' 'Clayey (Sét)']
#
# Column: Water_Availability_Cat
# ['Optimal' 'Moderate']
#
# Column: Extreme_Heat_Risk
# ['Low Risk' 'High Risk' 'Moderate Risk']

# %%
# 2. Định nghĩa các ngưỡng thực tế cho các chỉ số quan trọng
# Các giá trị ngoài khoảng này sẽ được coi là bất hợp lý
valid_ranges = {
    'Avg Temp': (5, 50),      # Nhiệt độ trung bình từ 5°C đến 50°C
    'pH': (3.5, 9.5),         # Độ pH đất nông nghiệp thường từ 3.5 đến 9.5
    'Avg Humidity': (10, 100),# Độ ẩm không khí từ 10% đến 100%
    'Rainfall': (0, 5000),    # Lượng mưa không thể âm
    'LST_Kelvin': (270, 330), # Nhiệt độ bề mặt (tương đương -3°C đến 57°C)
    'Nitrogen': (0, 100),     # Hàm lượng đạm (%)
    'Clay': (0, 100),         # % thành phần đất
    'Sand': (0, 100),
    'Silt': (0, 100)
}

# 3. Hàm xử lý dữ liệu bất hợp lý
def fix_invalid_data(df, ranges):
    df_cleaned = df.copy()
    for col, (min_val, max_val) in ranges.items():
        if col in df_cleaned.columns:
            # Đếm số lượng lỗi trước khi sửa
            invalid_mask = (df_cleaned[col] < min_val) | (df_cleaned[col] > max_val)
            num_invalid = invalid_mask.sum()
            
            if num_invalid > 0:
                print(f"Cột {col}: Phát hiện {num_invalid} giá trị bất hợp lý. Đang xử lý...")
                # Thay thế giá trị sai bằng Median của cột đó để tránh làm lệch dữ liệu
                median_val = df_cleaned[col].median()
                df_cleaned.loc[invalid_mask, col] = median_val
                
    return df_cleaned

# Thực hiện xóa/sửa dữ liệu sai
df_cleaned = fix_invalid_data(df, valid_ranges)

# 4. Kiểm tra logic tổng thành phần đất (Clay + Sand + Silt phải xấp xỉ 100%)
# Nếu tổng sai lệch quá nhiều (> 5%), chúng ta điều chỉnh tỷ lệ
soil_parts = ['Clay', 'Sand', 'Silt']
if all(col in df_cleaned.columns for col in soil_parts):
    soil_sum = df_cleaned[soil_parts].sum(axis=1)
    # Tìm các dòng có tổng sai lệch lớn hơn 1%
    bad_soil_logic = (soil_sum < 99) | (soil_sum > 101)
    if bad_soil_logic.any():
        print(f"Phát hiện {bad_soil_logic.sum()} dòng sai logic tổng thành phần đất. Đang chuẩn hóa...")
        # Chuẩn hóa về tỷ lệ 100%
        df_cleaned.loc[bad_soil_logic, soil_parts] = df_cleaned.loc[bad_soil_logic, soil_parts].div(soil_sum[bad_soil_logic], axis=0) * 100

# 5. Lưu kết quả
print("\n--- Hoàn thành xử lý dữ liệu bất hợp lý ---")
# Out:
# --- Hoàn thành xử lý dữ liệu bất hợp lý ---

# %%
import re
import calendar

# ===============================
# COPY DATA
# ===============================
df = df.copy()

# ===============================
# 1. CHUẨN HÓA TOÀN BỘ STRING
# ===============================
str_cols = df.select_dtypes(include="object").columns

for col in str_cols:
    df[col] = (
        df[col]
        .astype(str)
        .str.strip()
        .str.replace(r"\s+", " ", regex=True)
    )

# ===============================
# 2. CHUẨN HÓA TRANSPLANT (FULL MONTH NAME)
# ===============================
month_map = {
    'Jan': 'January', 'Feb': 'February',
    'Aug': 'August', 'Sep': 'September',
    'Oct': 'October', 'Nov': 'November',
    'Dec': 'December'
}

df['Transplant'] = df['Transplant'].replace(month_map)

# ===============================
# 3. FIX TYPO & CHUẨN HÓA TITLE CASE
# ===============================
cycle_cols = ['Transplant', 'Growth', 'Harvest']

df[cycle_cols] = df[cycle_cols].apply(lambda x: x.str.title())

df.replace({
    'Throuout The Year': 'Throughout The Year'
}, inplace=True)

# ===============================
# 4. IMPUTE CROP CYCLE THEO SEASON (VECTORIZE)
# ===============================
season_rules = {
    'Kharif 1': {
        'Transplant': 'March',
        'Growth': 'April To May',
        'Harvest': 'June'
    },
    'Kharif 2': {
        'Transplant': 'July',
        'Growth': 'August To October',
        'Harvest': 'November'
    },
    'Rabi': {
        'Transplant': 'November',
        'Growth': 'December To February',
        'Harvest': 'March'
    }
}

invalid_vals = ['No Need To Do', 'Throughout The Year']

for season, rules in season_rules.items():
    season_mask = df['Season'] == season
    
    for col in cycle_cols:
        invalid_mask = df[col].isin(invalid_vals)
        df.loc[season_mask & invalid_mask, col] = rules[col]

# ===============================
# 5. LOẠI BỎ TIẾNG VIỆT TRONG NGOẶC
# ===============================
df['pH_Suitability'] = df['pH_Suitability'].str.replace(r"\s*\(.*\)", "", regex=True)
df['Dominant_Soil_Texture'] = df['Dominant_Soil_Texture'].str.replace(r"\s*\(.*\)", "", regex=True)

# ===============================
# 6. DROP CỘT KHÔNG CÓ VARIANCE
# ===============================
low_variance_cols = [col for col in df.columns if df[col].nunique() <= 1]
df.drop(columns=low_variance_cols, inplace=True)

# ===============================
# 7. TÍNH THỜI GIAN SINH TRƯỞNG (THÁNG)
# ===============================
month_to_num = {month: index for index, month in enumerate(calendar.month_name) if month}

def duration_months(text):
    if isinstance(text, str) and "To" in text:
        parts = text.split("To")
        if len(parts) == 2:
            start = parts[0].strip()
            end = parts[1].strip()
            if start in month_to_num and end in month_to_num:
                return (month_to_num[end] - month_to_num[start]) % 12
    return np.nan

df['Growth_Duration_Months'] = df['Growth'].apply(duration_months)

# ===============================
# 8. VALIDATION
# ===============================
print("Shape after cleaning:", df.shape)
print("\nDropped columns:", low_variance_cols)
print("\nUnique Seasons:", df['Season'].unique())
print("\nUnique Transplant:", sorted(df['Transplant'].unique()))
print("\nSample Growth Duration:")
print(df[['Growth','Growth_Duration_Months']].head())
# Out:
# Shape after cleaning: (4178, 51)
#
# Dropped columns: ['Year', 'Compaction_Risk']
#
# Unique Seasons: ['Rabi' 'Kharif 1' 'Kharif 2']
#
# Unique Transplant: ['April', 'August', 'December', 'February', 'January', 'July', 'June', 'March', 'May', 'November', 'October', 'September']
#
# Sample Growth Duration:
#          Growth  Growth_Duration_Months
# 0  Jan To March                     NaN
# 1  Jan To March                     NaN
# 2  Dec To March                     NaN
# 3  Dec To March                     NaN
# 4  April To May                     1.0

# %%
str_cols = df.select_dtypes(include=['object']).columns

for col in str_cols:
    print(f"\nColumn: {col}")
    print(df[col].unique())
# Out:
# Column: District
# ['Bagerhat' 'Bandarban' 'Barguna' 'Barishal' 'Bhola' 'Bogura'
#  'Brahmanbaria' 'Chandpur' 'Chapai Nawabganj' 'Chattogram' 'Chuadanga'
#  'Coxsbazar' 'Cumilla' 'Dhaka' 'Dinajpur' 'Faridpur' 'Feni' 'Gaibandha'
#  'Gazipur' 'Gopalganj' 'Habiganj' 'Jamalpur' 'Jashore' 'Jhallokati'
#  'Jhenaidah' 'Joypurhat' 'Khagrachari' 'Khulna' 'Kishoreganj' 'Kurigram'
#  'Kushtia' 'Lakshmipur' 'Lalmonirhat' 'Madaripur' 'Magura' 'Manikganj'
#  'Meherpur' 'Moulvibazar' 'Munshiganj' 'Mymensingh' 'Naogaon' 'Narail'
#  'Narayanganj' 'Narsingdi' 'Natore' 'Netrokona' 'Nilphamari' 'Noakhali'
#  'Pabna' 'Panchagar' 'Patuakhali' 'Pirojpur' 'Rajbari' 'Rajshahi'
#  'Rangamati' 'Rangpur' 'Satkhira' 'Shariatpur' 'Sherpur' 'Sirajganj'
#  'Sunamganj' 'Sylhet' 'Tangail' 'Thakurgaon']
#
# Column: Season
# ['Rabi' 'Kharif 1' 'Kharif 2']
#
# Column: Crop Name
# ['Wheat' 'Maize 2' 'Boro' 'Sweet Potato' 'Mango' 'Jack Fruit'
#  'Ripe Papaya' 'Aus' 'Karala' 'Sugarcane' 'Green Papaya' 'Amra'
#  'Wood Apple' 'Green Coconut' 'Oal Kachu' 'Barbati' 'Puishak'
#  'Palong Shak' 'Sesame' 'Garlic' 'Cauliflower' 'Cabbage' 'Rape & Mustard'
#  'Date Palm' 'Lentil' 'Boroi' 'Taramind' 'Banana' 'Lemon' 'Safeda' 'Patal'
#  'Gourd' 'Betelnut' 'Chalkumra' 'Kakrol' 'Black Berry' 'Jamrul' 'Jhinga'
#  'Pineapple' 'Lady’S Finger' 'Carrot' 'Radish' 'Chili' 'Onion' 'Ginger'
#  'Motor' 'Groundnut' 'Cucumber' 'Green Palmyra' 'Mug' 'Jambura' 'Gram'
#  'Beans' 'Aman' 'Palmyra Palm' 'Pumpkin' 'Lal Shak' 'Laushak' 'Shalgom'
#  'Jute' 'Danta Shak' 'Danta' 'Mukhi Kachu' 'Kolmi Shak' 'Guava' 'Malta'
#  'Cheena' 'Tobacco' 'Maize 1' 'Arhar' 'Dalim' 'Mashkalai']
#
# Column: Transplant
# ['December' 'November' 'April' 'March' 'February' 'October' 'June' 'May'
#  'September' 'August' 'July' 'January']
#
# Column: Growth
# ['Jan To March' 'Dec To March' 'April To May' 'April To July'
#  'March To July' 'Nov To Aug' 'June To August' 'Oct To Dec' 'Sep To Jan'
#  'Dec To Jan' 'Nov To Jan' 'Oct To Jan' 'Nov To Feb'
#  'December To February' 'March To April' 'Jan To Jan' 'Aug To Jan'
#  'May To July' 'July To August' 'May To June' 'Sep To May' 'Nov To March'
#  'August To October' 'March To May' 'Sep To Oct' 'July To Nov'
#  'July To Oct' 'Oct To Nov' 'April To Aug' 'May To Sep' 'Dec To Feb']
#
# Column: Harvest
# ['April' 'April To June' 'April To May' 'Aug' 'Aug To Sep'
#  'August To September' 'Dec To Feb' 'December To April' 'Feb'
#  'Feb To April' 'Feb To March' 'February To March' 'February To May' 'Jan'
#  'Jan To March' 'July To Oct' 'July To Sep' 'June To September'
#  'June To Aug' 'June To Sep' 'March' 'March To April' 'March To Jun' 'May'
#  'May To June' 'Nov' 'Nov To April' 'Nov To Dec' 'Nov To Feb' 'Sep'
#  'Sep To Feb' 'Sep To Oct' 'June' 'June To July']
#
# Column: pH_Suitability
# ['Optimal' 'Acidic']
#
# Column: Dominant_Soil_Texture
# ['Loamy' 'Clayey']
#
# Column: Water_Availability_Cat
# ['Optimal' 'Moderate']
#
# Column: Extreme_Heat_Risk
# ['Low Risk' 'High Risk' 'Moderate Risk']

# %% [markdown]
# ## Bước 5 : Xử lý những giá trị ngoại lai

# %% [markdown]
# 1. Mục tiêu chiến dịchLoại bỏ nhiễu (noise) từ dữ liệu vệ tinh và thiết bị cảm biến, đồng thời bảo toàn tín hiệu thiên tai (Heat Stress, Wind Max) để không làm mất đi các yếu tố ảnh hưởng mạnh đến năng suất cây trồng.2. Các vấn đề đã khắc phụcTránh xử lý máy móc: Thay vì "cắt bằng" tất cả các cột, chúng ta đã phân loại biến theo đặc tính sinh học và khí tượng.Giảm sai lệch (Bias): Ngăn chặn việc mô hình bị chệch hướng bởi các giá trị quá lớn do lỗi thiết bị đo.Giữ dấu vết sự kiện: Đảm bảo các năm có thời tiết khắc nghiệt vẫn được mô hình ghi nhận thông qua cơ chế gắn thẻ (Flagging).3. Chiến lược xử lý chi tiếtA. Nhóm Chỉ số Vệ tinh & Đất (Capping)Danh sách: Nitrogen, Organic_Carbon, LAI, EVI, FPAR, AP Ratio, Humidity.Phương pháp: Sử dụng dải IQR (Interquartile Range).Công thức:$IQR = Q3 - Q1$$Lower\ Bound = Q1 - 1.5 \times IQR$$Upper\ Bound = Q3 + 1.5 \times IQR$Hành động: Thu gọn các giá trị nằm ngoài biên về giá trị biên gần nhất bằng np.clip.B. Nhóm Thời tiết Cực đoan (Flagging & Clipping)Danh sách: Heat_Stress_Days, Wind_Max.Hành động:Tạo cột đánh dấu: is_extreme_[Column] = 1 nếu là ngoại lai.Sau đó mới thực hiện thu gọn giá trị.Mục đích: Giúp mô hình học được rằng: "Đây là một năm có biến động lớn, cần chú ý đặc biệt đến năng suất".

# %%
def smart_agri_cleaner(df, capping_cols, extreme_event_cols):
    """
    Xử lý Outliers thông minh cho dữ liệu Nông nghiệp.
    - capping_cols: Các cột chỉ cần giới hạn biên (EVI, LAI, Dinh dưỡng đất).
    - extreme_event_cols: Các cột thời tiết cần đánh dấu thiên tai trước khi xử lý.
    """
    df_final = df.copy()
    
    # 1. Xử lý nhóm Biến Khí hậu (Cần đánh dấu trước khi Cap)
    for col in extreme_event_cols:
        if col in df_final.columns:
            Q1 = df_final[col].quantile(0.25)
            Q3 = df_final[col].quantile(0.75)
            IQR = Q3 - Q1
            upper_bound = Q3 + 1.5 * IQR
            
            # Tạo cột Flag: 1 nếu là thiên tai/cực đoan, 0 nếu bình thường
            df_final[f'is_extreme_{col}'] = (df_final[col] > upper_bound).astype(int)
            
            # Sau đó mới thực hiện Capping để ổn định phương sai cho mô hình
            df_final[col] = np.clip(df_final[col], None, upper_bound)
            print(f"[v] Đã Flag và Cap cột cực đoan: {col}")

    # 2. Xử lý nhóm Biến Chỉ số & Đất (Capping thông thường)
    for col in capping_cols:
        if col in df_final.columns:
            Q1 = df_final[col].quantile(0.25)
            Q3 = df_final[col].quantile(0.75)
            IQR = Q3 - Q1
            lower_bound = Q1 - 1.5 * IQR
            upper_bound = Q3 + 1.5 * IQR
            
            # Sử dụng np.clip để code gọn và nhanh hơn np.where
            df_final[col] = np.clip(df_final[col], lower_bound, upper_bound)
    
    print(f"[-] Hoàn thành xử lý {len(capping_cols) + len(extreme_event_cols)} cột.")
    return df_final

# --- ÁP DỤNG VÀO DỮ LIỆU CỦA BẠN ---

# Nhóm 1: Các biến chỉ số (Vệ tinh, Đất, Độ ẩm) - Dùng Capping
capping_list = [
     'Nitrogen', 'LAI', 'Organic_Carbon',
    'Max Relative Humidity', 'Min Relative Humidity', 'Avg Humidity', 'EVI', 'FPAR'
]

# Nhóm 2: Các biến có tính "Thiên tai/Cực đoan" - Dùng Flagging + Capping
extreme_list = ['Heat_Stress_Days', 'Wind_Max']

# Thực hiện xử lý
df = smart_agri_cleaner(df, capping_list, extreme_list)
df.to_csv('Agri_Data_Cleaned.csv', index=False, encoding='utf-8-sig')
# Out:
# [v] Đã Flag và Cap cột cực đoan: Heat_Stress_Days
# [v] Đã Flag và Cap cột cực đoan: Wind_Max
# [-] Hoàn thành xử lý 10 cột.

# %%
df.head()
# Out:
#      Area  AP Ratio  District    Season  Avg Temp  Avg Humidity     Crop Name  \
# 0     259  0.772201  Bagerhat      Rabi     17.75          55.0         Wheat
# 1     421  2.247031  Bagerhat      Rabi     20.50          60.0       Maize 2
# 2  145439  1.847881  Bagerhat      Rabi     26.00          72.5          Boro
# 3     627  3.508772  Bagerhat      Rabi     20.50          80.0  Sweet Potato
# 4     383  4.994778  Bagerhat  Kharif 1     31.50          70.0         Mango
#
#   Transplant        Growth        Harvest  ...  Heat_Stress_Days  Wind_Mean  \
# 0   December  Jan To March          April  ...               0.0   1.452917
# 1   December  Jan To March          April  ...               0.0   1.452917
# 2   November  Dec To March          April  ...               0.0   1.452917
# 3   November  Dec To March          April  ...               0.0   1.452917
# 4      April  April To May  April To June  ...              42.5   2.481885
#
#    Wind_Max  Wind_Min  Rain_Temp_Ratio  Extreme_Heat_Risk  Is_Extreme_Heat  \
# 0      4.33      0.04            11.23           Low Risk                0
# 1      4.33      0.04            11.23           Low Risk                0
# 2      4.33      0.04            11.23           Low Risk                0
# 3      4.33      0.04            11.23           Low Risk                0
# 4      5.86      0.04            22.73          High Risk                1
#
#    Growth_Duration_Months  is_extreme_Heat_Stress_Days  is_extreme_Wind_Max
# 0                     NaN                            0                    0
# 1                     NaN                            0                    0
# 2                     NaN                            0                    0
# 3                     NaN                            0                    0
# 4                     1.0                            1                    0
#
# [5 rows x 53 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4178 entries, 0 to 4607
# Data columns (total 53 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Area                         4178 non-null   int64
#  1   AP Ratio                     4178 non-null   float64
#  2   District                     4178 non-null   object
#  3   Season                       4178 non-null   object
#  4   Avg Temp                     4178 non-null   float64
#  5   Avg Humidity                 4178 non-null   float64
#  6   Crop Name                    4178 non-null   object
#  7   Transplant                   4178 non-null   object
#  8   Growth                       4178 non-null   object
#  9   Harvest                      4178 non-null   object
#  10  Production                   4178 non-null   int64
#  11  Max Temp                     4178 non-null   int64
#  12  Min Temp                     4178 non-null   float64
#  13  Max Relative Humidity        4178 non-null   int64
#  14  Min Relative Humidity        4178 non-null   int64
#  15  EVI                          4178 non-null   float64
#  16  LAI                          4178 non-null   float64
#  17  FPAR                         4178 non-null   float64
#  18  LST_Kelvin                   4178 non-null   float64
#  19  Soil_Moisture_mm             4178 non-null   float64
#  20  NDVI_Season_Mean             4178 non-null   float64
#  21  NDVI_Season_Max              4178 non-null   float64
#  22  NDVI_Season_Min              4178 non-null   float64
#  23  NDVI_Season_Std              4178 non-null   float64
#  24  NDVI_Season_Range            4178 non-null   float64
#  25  NDVI_Season_CV               4178 non-null   float64
#  26  Avg_Salinity_Index           4178 non-null   float64
#  27  pH                           4178 non-null   float64
#  28  Organic_Carbon               4178 non-null   float64
#  29  Nitrogen                     4178 non-null   float64
#  30  Clay                         4178 non-null   float64
#  31  Sand                         4178 non-null   float64
#  32  Silt                         4178 non-null   float64
#  33  Bulk_Density                 4178 non-null   float64
#  34  CN_Ratio                     4178 non-null   float64
#  35  pH_Suitability               4178 non-null   object
#  36  Dominant_Soil_Texture        4178 non-null   object
#  37  sm_surface                   4178 non-null   float64
#  38  sm_rootzone                  4178 non-null   float64
#  39  Rootzone_Surface_Diff        4178 non-null   float64
#  40  Moisture_Ratio               4178 non-null   float64
#  41  Water_Availability_Cat       4178 non-null   object
#  42  Rainfall                     4178 non-null   float64
#  43  Heat_Stress_Days             4178 non-null   float64
#  44  Wind_Mean                    4178 non-null   float64
#  45  Wind_Max                     4178 non-null   float64
#  46  Wind_Min                     4178 non-null   float64
#  47  Rain_Temp_Ratio              4178 non-null   float64
#  48  Extreme_Heat_Risk            4178 non-null   object
#  49  Is_Extreme_Heat              4178 non-null   int64
#  50  Growth_Duration_Months       1564 non-null   float64
#  51  is_extreme_Heat_Stress_Days  4178 non-null   int64
#  52  is_extreme_Wind_Max          4178 non-null   int64
# dtypes: float64(35), int64(8), object(10)
# memory usage: 1.7+ MB

# %%
str_cols = df.select_dtypes(include=['object']).columns

for col in str_cols:
    print(f"\nColumn: {col}")
    print(df[col].unique())
# Out:
# Column: District
# ['Bagerhat' 'Bandarban' 'Barguna' 'Barishal' 'Bhola' 'Bogura'
#  'Brahmanbaria' 'Chandpur' 'Chapai Nawabganj' 'Chattogram' 'Chuadanga'
#  'Coxsbazar' 'Cumilla' 'Dhaka' 'Dinajpur' 'Faridpur' 'Feni' 'Gaibandha'
#  'Gazipur' 'Gopalganj' 'Habiganj' 'Jamalpur' 'Jashore' 'Jhallokati'
#  'Jhenaidah' 'Joypurhat' 'Khagrachari' 'Khulna' 'Kishoreganj' 'Kurigram'
#  'Kushtia' 'Lakshmipur' 'Lalmonirhat' 'Madaripur' 'Magura' 'Manikganj'
#  'Meherpur' 'Moulvibazar' 'Munshiganj' 'Mymensingh' 'Naogaon' 'Narail'
#  'Narayanganj' 'Narsingdi' 'Natore' 'Netrokona' 'Nilphamari' 'Noakhali'
#  'Pabna' 'Panchagar' 'Patuakhali' 'Pirojpur' 'Rajbari' 'Rajshahi'
#  'Rangamati' 'Rangpur' 'Satkhira' 'Shariatpur' 'Sherpur' 'Sirajganj'
#  'Sunamganj' 'Sylhet' 'Tangail' 'Thakurgaon']
#
# Column: Season
# ['Rabi' 'Kharif 1' 'Kharif 2']
#
# Column: Crop Name
# ['Wheat' 'Maize 2' 'Boro' 'Sweet Potato' 'Mango' 'Jack Fruit'
#  'Ripe Papaya' 'Aus' 'Karala' 'Sugarcane' 'Green Papaya' 'Amra'
#  'Wood Apple' 'Green Coconut' 'Oal Kachu' 'Barbati' 'Puishak'
#  'Palong Shak' 'Sesame' 'Garlic' 'Cauliflower' 'Cabbage' 'Rape & Mustard'
#  'Date Palm' 'Lentil' 'Boroi' 'Taramind' 'Banana' 'Lemon' 'Safeda' 'Patal'
#  'Gourd' 'Betelnut' 'Chalkumra' 'Kakrol' 'Black Berry' 'Jamrul' 'Jhinga'
#  'Pineapple' 'Lady’S Finger' 'Carrot' 'Radish' 'Chili' 'Onion' 'Ginger'
#  'Motor' 'Groundnut' 'Cucumber' 'Green Palmyra' 'Mug' 'Jambura' 'Gram'
#  'Beans' 'Aman' 'Palmyra Palm' 'Pumpkin' 'Lal Shak' 'Laushak' 'Shalgom'
#  'Jute' 'Danta Shak' 'Danta' 'Mukhi Kachu' 'Kolmi Shak' 'Guava' 'Malta'
#  'Cheena' 'Tobacco' 'Maize 1' 'Arhar' 'Dalim' 'Mashkalai']
#
# Column: Transplant
# ['December' 'November' 'April' 'March' 'February' 'October' 'June' 'May'
#  'September' 'August' 'July' 'January']
#
# Column: Growth
# ['Jan To March' 'Dec To March' 'April To May' 'April To July'
#  'March To July' 'Nov To Aug' 'June To August' 'Oct To Dec' 'Sep To Jan'
#  'Dec To Jan' 'Nov To Jan' 'Oct To Jan' 'Nov To Feb'
#  'December To February' 'March To April' 'Jan To Jan' 'Aug To Jan'
#  'May To July' 'July To August' 'May To June' 'Sep To May' 'Nov To March'
#  'August To October' 'March To May' 'Sep To Oct' 'July To Nov'
#  'July To Oct' 'Oct To Nov' 'April To Aug' 'May To Sep' 'Dec To Feb']
#
# Column: Harvest
# ['April' 'April To June' 'April To May' 'Aug' 'Aug To Sep'
#  'August To September' 'Dec To Feb' 'December To April' 'Feb'
#  'Feb To April' 'Feb To March' 'February To March' 'February To May' 'Jan'
#  'Jan To March' 'July To Oct' 'July To Sep' 'June To September'
#  'June To Aug' 'June To Sep' 'March' 'March To April' 'March To Jun' 'May'
#  'May To June' 'Nov' 'Nov To April' 'Nov To Dec' 'Nov To Feb' 'Sep'
#  'Sep To Feb' 'Sep To Oct' 'June' 'June To July']
#
# Column: pH_Suitability
# ['Optimal' 'Acidic']
#
# Column: Dominant_Soil_Texture
# ['Loamy' 'Clayey']
#
# Column: Water_Availability_Cat
# ['Optimal' 'Moderate']
#
# Column: Extreme_Heat_Risk
# ['Low Risk' 'High Risk' 'Moderate Risk']

# %% [markdown]
# #### tạo ra cột Yeild và xóa bỏ drop bỏ những cột Growth

# %%
df = df.drop('Growth_Duration_Months', axis=1)
df['Yield'] = df['Production'] / df['Area']
df.to_csv('Agri_Data_Cleaned.csv', index=False, encoding='utf-8-sig')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4178 entries, 0 to 4607
# Data columns (total 53 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Area                         4178 non-null   int64
#  1   AP Ratio                     4178 non-null   float64
#  2   District                     4178 non-null   object
#  3   Season                       4178 non-null   object
#  4   Avg Temp                     4178 non-null   float64
#  5   Avg Humidity                 4178 non-null   float64
#  6   Crop Name                    4178 non-null   object
#  7   Transplant                   4178 non-null   object
#  8   Growth                       4178 non-null   object
#  9   Harvest                      4178 non-null   object
#  10  Production                   4178 non-null   int64
#  11  Max Temp                     4178 non-null   int64
#  12  Min Temp                     4178 non-null   float64
#  13  Max Relative Humidity        4178 non-null   int64
#  14  Min Relative Humidity        4178 non-null   int64
#  15  EVI                          4178 non-null   float64
#  16  LAI                          4178 non-null   float64
#  17  FPAR                         4178 non-null   float64
#  18  LST_Kelvin                   4178 non-null   float64
#  19  Soil_Moisture_mm             4178 non-null   float64
#  20  NDVI_Season_Mean             4178 non-null   float64
#  21  NDVI_Season_Max              4178 non-null   float64
#  22  NDVI_Season_Min              4178 non-null   float64
#  23  NDVI_Season_Std              4178 non-null   float64
#  24  NDVI_Season_Range            4178 non-null   float64
#  25  NDVI_Season_CV               4178 non-null   float64
#  26  Avg_Salinity_Index           4178 non-null   float64
#  27  pH                           4178 non-null   float64
#  28  Organic_Carbon               4178 non-null   float64
#  29  Nitrogen                     4178 non-null   float64
#  30  Clay                         4178 non-null   float64
#  31  Sand                         4178 non-null   float64
#  32  Silt                         4178 non-null   float64
#  33  Bulk_Density                 4178 non-null   float64
#  34  CN_Ratio                     4178 non-null   float64
#  35  pH_Suitability               4178 non-null   object
#  36  Dominant_Soil_Texture        4178 non-null   object
#  37  sm_surface                   4178 non-null   float64
#  38  sm_rootzone                  4178 non-null   float64
#  39  Rootzone_Surface_Diff        4178 non-null   float64
#  40  Moisture_Ratio               4178 non-null   float64
#  41  Water_Availability_Cat       4178 non-null   object
#  42  Rainfall                     4178 non-null   float64
#  43  Heat_Stress_Days             4178 non-null   float64
#  44  Wind_Mean                    4178 non-null   float64
#  45  Wind_Max                     4178 non-null   float64
#  46  Wind_Min                     4178 non-null   float64
#  47  Rain_Temp_Ratio              4178 non-null   float64
#  48  Extreme_Heat_Risk            4178 non-null   object
#  49  Is_Extreme_Heat              4178 non-null   int64
#  50  is_extreme_Heat_Stress_Days  4178 non-null   int64
#  51  is_extreme_Wind_Max          4178 non-null   int64
#  52  Yield                        4178 non-null   float64
# dtypes: float64(35), int64(8), object(10)
# memory usage: 1.7+ MB

# %%
#1. Hiện trạng và Vấn đề phát hiện
#Trong quá trình kiểm tra (Exploratory Data Analysis - EDA) bộ dữ liệu Agri_Data_Cleaned.csv, chúng ta đã phát hiện một sự bất thường nghiêm trọng ở biến số Yield (Năng suất):

#Mặc dù trung vị (Median) của toàn bộ Năng suất chỉ ở mức ~2.53, và bách phân vị thứ 99 (p99) là ~29.16, nhưng giá trị Max lại vọt lên tới 951.22.

#Khi đi sâu vào phân tích, toàn bộ các quan sát có Yield > 100 đều thuộc về loại cây trồng là Jack Fruit (Mít).

#Về mặt kiến thức thực tế (Domain knowledge), năng suất Mít tại khu vực Nam Á (như Bangladesh) chỉ dao động trung bình từ 15 đến 30 tấn/ha. Việc năng suất đạt từ hàng trăm đến gần một ngàn tấn là vô lý.

#2. Chẩn đoán Nguyên nhân
#Người nhập liệu đã nhầm lẫn giữa dấu chấm thập phân (.) và dấu phẩy phân cách hàng nghìn (,).

#Ví dụ thực tế trong dữ liệu: Một quan sát có Area = 60, Production = 57,073. Đáng lẽ giá trị thật phải là 57.073 tấn (57 phẩy 073), nhưng hệ thống ghi nhận thành 57 ngàn 073 tấn.

#Hậu quả: Cột Production (Sản lượng) bị nhân lên 1000 lần, kéo theo cột Yield (= Production / Area) và AP Ratio bị sai lệch khổng lồ.

#3. Phương pháp Xác định (Detection Method)
#Thay vì sử dụng các ngưỡng cố định mang tính chủ quan (ví dụ: gán cứng Yield > 100), chúng ta đã áp dụng các thuật toán chuẩn mực trong Khoa học dữ liệu để máy tính tự động nhận diện:

#Phương pháp sử dụng: Biểu đồ hộp Box Plot kết hợp với Khoảng tứ phân vị (IQR). (Đã được kiểm chứng chéo và cho kết quả khớp 100% với phương pháp Phân phối chuẩn kháng nhiễu - Robust Normal Distribution).

#Kết quả tính toán: Thuật toán xác định ngưỡng trên an toàn (Upper bound) của Năng suất Mít là 75.25 tấn/ha.

#Phát hiện: Thuật toán tự động quét và "bắt" gọn chính xác 12 dòng dữ liệu bị lỗi vượt quá ngưỡng an toàn này.

#4. Giải pháp Xử lý (Data Fixing/Correction)
#Để tránh mất mát dữ liệu (Data Loss) do việc xóa bỏ (Drop) mang lại, chúng ta chọn phương án khôi phục lại giá trị gốc:

#Lọc ra đúng 12 dòng ngoại lệ của Jack Fruit đã được Box Plot xác định.

#Điều chỉnh biến Production bằng cách chia cho 1000 để trả lại giá trị thập phân chính xác.

#Cập nhật (Recalculate) lại biến Yield và AP Ratio theo số liệu Production mới.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Tải dữ liệu và lọc riêng Mít (Jack Fruit)
df = pd.read_csv('Agri_Data_Cleaned.csv')
jf_data = df[df['Crop Name'] == 'Jack Fruit']

# 2. Vẽ biểu đồ Box Plot để quan sát bằng mắt
plt.figure(figsize=(10, 4))
sns.boxplot(x=jf_data['Yield'], color='skyblue')
plt.title('Phân phối Năng suất (Yield) của Mít (Jack Fruit)')
plt.xlabel('Năng suất (Tấn/ha)')
plt.tight_layout()
plt.savefig('jackfruit_boxplot.png') # Lưu ảnh
plt.show()

# 3. Tính toán các ngưỡng để lọc tự động
Q1 = jf_data['Yield'].quantile(0.25)
Q3 = jf_data['Yield'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# 4. Trích xuất các dòng là Ngoại lệ (Outliers)
outliers = jf_data[(jf_data['Yield'] < lower_bound) | (jf_data['Yield'] > upper_bound)]

print(f"Ngưỡng trên an toàn của Box Plot là: {upper_bound:.2f}")
print(f"Số lượng ngoại lệ phát hiện: {len(outliers)}")
print("\nDanh sách các ngoại lệ bị bắt:")
print(outliers[['Production', 'Area', 'Yield']].sort_values('Yield'))
# Out:
# Ngưỡng trên an toàn của Box Plot là: 75.25
# Số lượng ngoại lệ phát hiện: 12
#
# Danh sách các ngoại lệ bị bắt:
#       Production  Area       Yield
# 647         5560    70   79.428571
# 2352        9716   116   83.758621
# 3204       26144   250  104.576000
# 1433       11311   100  113.110000
# 1826       25718   200  128.590000
# 388        20907   150  139.380000
# 3791       12164    80  152.050000
# 3007       32199   170  189.405882
# 3858       18969    94  201.797872
# 1962       82756   300  275.853333
# 1363       28681   100  286.810000
# 2942       57073    60  951.216667

# %%
import pandas as pd

# 1. Tải dữ liệu
df = pd.read_csv('Agri_Data_Cleaned.csv')

# 2. Tính toán ngưỡng ngoại lệ của Box Plot cho riêng Jack Fruit
jf_data = df[df['Crop Name'] == 'Jack Fruit']
Q1 = jf_data['Yield'].quantile(0.25)
Q3 = jf_data['Yield'].quantile(0.75)
IQR = Q3 - Q1
upper_bound = Q3 + 1.5 * IQR

print(f"Ngưỡng trên (Upper Bound) của Jack Fruit: {upper_bound:.2f}")

# 3. Lọc ra các dòng ngoại lệ của Jack Fruit vượt ngưỡng trên trong DataFrame chính
outlier_condition = (df['Crop Name'] == 'Jack Fruit') & (df['Yield'] > upper_bound)
print(f"Số lượng dòng ngoại lệ phát hiện và chuẩn bị sửa: {outlier_condition.sum()}")

# 4. Sửa lỗi: Giảm Production đi 1000 lần cho các dòng này
df.loc[outlier_condition, 'Production'] = df.loc[outlier_condition, 'Production'] / 100

# 5. Cập nhật lại Yield và AP Ratio theo Production mới
df.loc[outlier_condition, 'Yield'] = df.loc[outlier_condition, 'Production'] / df.loc[outlier_condition, 'Area']
df.loc[outlier_condition, 'AP Ratio'] = df.loc[outlier_condition, 'Yield']

# 6. Kiểm tra qua một số dòng sau khi sửa
print("\n--- Dữ liệu của các dòng lỗi sau khi được sửa (chia 100) ---")
print(df.loc[outlier_condition, ['Crop Name', 'Area', 'Production', 'Yield']])

# 7. Lưu lại file CSV mới
df.to_csv('Agri_Data_Cleaned_Fixed_Boxplot.csv', index=False)
print("\nĐã lưu file: Agri_Data_Cleaned_Fixed_Boxplot.csv")
# Out:
# Ngưỡng trên (Upper Bound) của Jack Fruit: 75.25
# Số lượng dòng ngoại lệ phát hiện và chuẩn bị sửa: 12
#
# --- Dữ liệu của các dòng lỗi sau khi được sửa (chia 100) ---
#        Crop Name  Area  Production     Yield
# 388   Jack Fruit   150      209.07  1.393800
# 647   Jack Fruit    70       55.60  0.794286
# 1363  Jack Fruit   100      286.81  2.868100
# 1433  Jack Fruit   100      113.11  1.131100
# 1826  Jack Fruit   200      257.18  1.285900
# 1962  Jack Fruit   300      827.56  2.758533
# 2352  Jack Fruit   116       97.16  0.837586
# 2942  Jack Fruit    60      570.73  9.512167
# 3007  Jack Fruit   170      321.99  1.894059
# 3204  Jack Fruit   250      261.44  1.045760
# 3791  Jack Fruit    80      121.64  1.520500
# 3858  Jack Fruit    94      189.69  2.017979
#
# Đã lưu file: Agri_Data_Cleaned_Fixed_Boxplot.csv
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12304\1021501000.py:20: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[209.07  55.6  286.81 113.11 257.18 827.56  97.16 570.73 321.99 261.44
#  121.64 189.69]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[outlier_condition, 'Production'] = df.loc[outlier_condition, 'Production'] / 100
