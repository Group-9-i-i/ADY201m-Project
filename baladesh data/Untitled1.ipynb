# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv('database_tong.csv')
df.head()
# Out:
#      Area      AP Ratio   District    Season  Avg Temp  Avg Humidity  \
# 0  177321  0.8510272331   Bagerhat  Kharif 2      26.0          72.5
# 1   25646   1.175777899  Bandarban  Kharif 2      26.0          72.5
# 2  231401  0.7705887183    Barguna  Kharif 2      26.0          72.5
# 3  302665  0.7571043893   Barishal  Kharif 2      26.0          72.5
# 4  388575   1.100652384      Bhola  Kharif 2      26.0          72.5
#
#   Crop Name Transplant        Growth     Harvest  ...  valid_points  grid_log  \
# 0      Aman       June  July to  Oct  Nov to Dec  ...             5    ✅⚠️✅✅✅
# 1      Aman       June  July to  Oct  Nov to Dec  ...             5     ✅✅✅✅✅
# 2      Aman       June  July to  Oct  Nov to Dec  ...             5   ✅✅✅⚠️⚠️
# 3      Aman       June  July to  Oct  Nov to Dec  ...             5   ⚠️⚠️✅✅✅
# 4      Aman       June  July to  Oct  Nov to Dec  ...             3     ✅✅❌❌✅
#
#     Latitude  Longitude  Rainfall  Temp_Mean  Temp_Max  Temp_Min  \
# 0  22.655478  89.794181   1451.65  27.768699     33.57     18.56
# 1  21.787476  92.412475   1354.97  26.048780     32.68     17.05
# 2  22.131336  90.117243   1785.97  28.127317     32.51     20.84
# 3  22.493403  90.354801   1601.92  27.991220     32.47     19.53
# 4  22.143569  90.790409   2272.77  28.436423     31.57     21.83
#
#    Heat_Stress_Days  Year
# 0                 0  2022
# 1                 0  2022
# 2                 0  2022
# 3                 0  2022
# 4                 0  2022
#
# [5 rows x 43 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4535 entries, 0 to 4534
# Data columns (total 43 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Area                   4535 non-null   int64
#  1   AP Ratio               4535 non-null   str
#  2   District               4535 non-null   str
#  3   Season                 4535 non-null   str
#  4   Avg Temp               4535 non-null   float64
#  5   Avg Humidity           4535 non-null   float64
#  6   Crop Name              4535 non-null   str
#  7   Transplant             4535 non-null   str
#  8   Growth                 4535 non-null   str
#  9   Harvest                4535 non-null   str
#  10  Production             4535 non-null   int64
#  11  Max Temp               4535 non-null   int64
#  12  Min Temp               4535 non-null   float64
#  13  Max Relative Humidity  4535 non-null   int64
#  14  Min Relative Humidity  4535 non-null   int64
#  15  soil_ph                4535 non-null   float64
#  16  NDVI_early             4535 non-null   float64
#  17  NDVI_mid               4535 non-null   float64
#  18  NDVI_late              4535 non-null   float64
#  19  NDVI_std               4535 non-null   float64
#  20  NDVI_prev_season       4535 non-null   float64
#  21  EVI_Season             4535 non-null   float64
#  22  LAI_Season             4535 non-null   float64
#  23  FPAR_Season            4535 non-null   float64
#  24  LST_Season             4535 non-null   float64
#  25  Soil_Moisture_Season   4535 non-null   float64
#  26  pH                     4535 non-null   float64
#  27  Organic_Carbon         4535 non-null   float64
#  28  Nitrogen               4535 non-null   float64
#  29  Clay                   4535 non-null   float64
#  30  Sand                   4535 non-null   float64
#  31  Silt                   4535 non-null   float64
#  32  Bulk_Density           4535 non-null   float64
#  33  valid_points           4535 non-null   int64
#  34  grid_log               4535 non-null   str
#  35  Latitude               4535 non-null   float64
#  36  Longitude              4535 non-null   float64
#  37  Rainfall               4535 non-null   float64
#  38  Temp_Mean              4535 non-null   float64
#  39  Temp_Max               4535 non-null   float64
#  40  Temp_Min               4535 non-null   float64
#  41  Heat_Stress_Days       4535 non-null   int64
#  42  Year                   4535 non-null   int64
# dtypes: float64(27), int64(8), str(8)
# memory usage: 1.5 MB

# %%
df.isnull().sum()
# Out:
# Area                     0
# AP Ratio                 0
# District                 0
# Season                   0
# Avg Temp                 0
# Avg Humidity             0
# Crop Name                0
# Transplant               0
# Growth                   0
# Harvest                  0
# Production               0
# Max Temp                 0
# Min Temp                 0
# Max Relative Humidity    0
# Min Relative Humidity    0
# soil_ph                  0
# NDVI_early               0
# NDVI_mid                 0
# NDVI_late                0
# NDVI_std                 0
# NDVI_prev_season         0
# EVI_Season               0
# LAI_Season               0
# FPAR_Season              0
# LST_Season               0
# Soil_Moisture_Season     0
# pH                       0
# Organic_Carbon           0
# Nitrogen                 0
# Clay                     0
# Sand                     0
# Silt                     0
# Bulk_Density             0
# valid_points             0
# grid_log                 0
# Latitude                 0
# Longitude                0
# Rainfall                 0
# Temp_Mean                0
# Temp_Max                 0
# Temp_Min                 0
# Heat_Stress_Days         0
# Year                     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Xóa các cột có giá trị trùng lặp nếu trống hơn 50 phần trăm cột

# %%
limit = len(df.columns) * 0.5
df_cleaned = df.dropna(thresh=limit)
df_cleaned = df_cleaned.drop_duplicates()
